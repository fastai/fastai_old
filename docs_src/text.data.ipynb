# %% [markdown]
# # text.data

# %% [markdown]
# Type an introduction of the package here.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.text.data import *

# %% [markdown]
# ### Global Variable Definitions:

# %% [markdown]
# `TextMtd = IntEnum('TextMtd', 'CSV TOK IDS')` <div style="text-align: right"><a href="../fastai/text/data.py#L7">[source]</a></div>

# %%
show_doc(LanguageModelLoader)

# %% [markdown]
# [<code>LanguageModelLoader</code>](http://docs.fast.ai/text.data.html#LanguageModelLoader)

# %%
show_doc(LanguageModelLoader.batchify)

# %% [markdown]
# `LanguageModelLoader.batchify`

# %%
show_doc(LanguageModelLoader.get_batch)

# %% [markdown]
# `LanguageModelLoader.get_batch`

# %%
show_doc(SortSampler)

# %% [markdown]
# [<code>SortSampler</code>](http://docs.fast.ai/text.data.html#SortSampler)

# %%
show_doc(SortishSampler)

# %% [markdown]
# [<code>SortishSampler</code>](http://docs.fast.ai/text.data.html#SortishSampler)

# %%
show_doc(TextDataset)

# %% [markdown]
# [<code>TextDataset</code>](http://docs.fast.ai/text.data.html#TextDataset)

# %%
show_doc(TextDataset.check_ids)

# %% [markdown]
# `TextDataset.check_ids`

# %%
show_doc(TextDataset.check_toks)

# %% [markdown]
# `TextDataset.check_toks`

# %%
show_doc(TextDataset.clear)

# %% [markdown]
# `TextDataset.clear`

# %%
show_doc(TextDataset.from_csv)

# %% [markdown]
# `TextDataset.from_csv`

# %%
show_doc(TextDataset.from_folder)

# %% [markdown]
# `TextDataset.from_folder`

# %%
show_doc(TextDataset.from_ids)

# %% [markdown]
# `TextDataset.from_ids`

# %%
show_doc(TextDataset.from_tokens)

# %% [markdown]
# `TextDataset.from_tokens`

# %%
show_doc(TextDataset.general_check)

# %% [markdown]
# `TextDataset.general_check`

# %%
show_doc(TextDataset.numericalize)

# %% [markdown]
# `TextDataset.numericalize`

# %%
show_doc(TextDataset.tokenize)

# %% [markdown]
# `TextDataset.tokenize`

# %%
show_doc(TextMtd)

# %% [markdown]
# [<code>TextMtd</code>](http://docs.fast.ai/text.data.html#TextMtd)

# %%
show_doc(classifier_data)

# %% [markdown]
# [<code>classifier_data</code>](http://docs.fast.ai/text.data.html#classifier_data)

# %%
show_doc(lm_data)

# %% [markdown]
# [<code>lm_data</code>](http://docs.fast.ai/text.data.html#lm_data)

# %%
show_doc(pad_collate)

# %% [markdown]
# [<code>pad_collate</code>](http://docs.fast.ai/text.data.html#pad_collate)

# %%
show_doc(standard_data)

# %% [markdown]
# [<code>standard_data</code>](http://docs.fast.ai/text.data.html#standard_data)

# %%
show_doc(text_data_from_csv)

# %% [markdown]
# [<code>text_data_from_csv</code>](http://docs.fast.ai/text.data.html#text_data_from_csv)

# %%
show_doc(text_data_from_folder)

# %% [markdown]
# [<code>text_data_from_folder</code>](http://docs.fast.ai/text.data.html#text_data_from_folder)

# %%
show_doc(text_data_from_ids)

# %% [markdown]
# [<code>text_data_from_ids</code>](http://docs.fast.ai/text.data.html#text_data_from_ids)

# %%
show_doc(text_data_from_tokens)

# %% [markdown]
# [<code>text_data_from_tokens</code>](http://docs.fast.ai/text.data.html#text_data_from_tokens)
