# %% [markdown]
# # vision.data

# %% [markdown]
# Type an introduction of the package here.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.vision.data import *

# %% [markdown]
# ### Global Variable Definitions:

# %%
show_doc(CoordTargetDataset)

# %% [markdown]
# [<code>CoordTargetDataset</code>](http://docs.fast.ai/vision.data.html#CoordTargetDataset)

# %%
show_doc(DatasetTfm)

# %% [markdown]
# [<code>DatasetTfm</code>](http://docs.fast.ai/vision.data.html#DatasetTfm)

# %%
show_doc(FilesDataset)

# %% [markdown]
# `FilesDataset`

# %%
show_doc(FilesDataset._folder_files)

# %% [markdown]
# `FilesDataset._folder_files`

# %%
show_doc(FilesDataset.from_folder)

# %% [markdown]
# `FilesDataset.from_folder`

# %%
show_doc(FilesDataset.from_single_folder)

# %% [markdown]
# `FilesDataset.from_single_folder`

# %%
show_doc(image_data_from_csv)

# %%
show_doc(ImageDataset)

# %%
show_doc(ImageDataset._folder_files)

# %%
show_doc(ImageDataset.from_folder)

# %%
show_doc(ImageDataset.from_single_folder)

# %%
show_doc(ImageMultiDataset)

# %%
show_doc(ImageMultiDataset.encode)

# %%
show_doc(ImageMultiDataset.from_folder)

# %%
show_doc(ImageMultiDataset.from_single_folder)

# %%
show_doc(ImageMultiDataset.get_labels)

# %%
show_doc(SegmentationDataset)

# %% [markdown]
# [<code>SegmentationDataset</code>](http://docs.fast.ai/vision.data.html#SegmentationDataset)

# %%
show_doc(bb2hw)

# %% [markdown]
# [<code>bb2hw</code>](http://docs.fast.ai/vision.image.html#bb2hw)

# %%
show_doc(denormalize)

# %% [markdown]
# [<code>denormalize</code>](http://docs.fast.ai/vision.data.html#denormalize)

# %%
show_doc(draw_outline)

# %% [markdown]
# [<code>draw_outline</code>](fastai.vision.image.html#draw_outline)

# %%
show_doc(draw_rect)

# %% [markdown]
# [<code>draw_rect</code>](fastai.vision.image.html#draw_rect)

# %%
show_doc(get_image_files)

# %% [markdown]
# [<code>get_image_files</code>](http://docs.fast.ai/vision.data.html#get_image_files)

# %%
show_doc(image2np)

# %% [markdown]
# [<code>image2np</code>](http://docs.fast.ai/vision.image.html#image2np)

# %%
show_doc(image_data_from_folder)

# %% [markdown]
# [<code>image_data_from_folder</code>](http://docs.fast.ai/vision.data.html#image_data_from_folder)

# %%
show_doc(normalize)

# %% [markdown]
# [<code>normalize</code>](http://docs.fast.ai/vision.data.html#normalize)

# %%
show_doc(normalize_batch)

# %% [markdown]
# [<code>normalize_batch</code>](http://docs.fast.ai/vision.data.html#normalize_batch)

# %%
show_doc(normalize_funcs)

# %% [markdown]
# [<code>normalize_funcs</code>](http://docs.fast.ai/vision.data.html#normalize_funcs)

# %%
show_doc(open_image)

# %% [markdown]
# [<code>open_image</code>](http://docs.fast.ai/vision.image.html#open_image)

# %%
show_doc(open_mask)

# %% [markdown]
# [<code>open_mask</code>](http://docs.fast.ai/vision.image.html#open_mask)

# %%
show_doc(pil2tensor)

# %% [markdown]
# [<code>pil2tensor</code>](http://docs.fast.ai/vision.image.html#pil2tensor)

# %%
show_doc(show_image)

# %% [markdown]
# [<code>show_image</code>](http://docs.fast.ai/vision.image.html#show_image)

# %%
show_doc(show_image_batch)

# %% [markdown]
# [<code>show_image_batch</code>](http://docs.fast.ai/vision.data.html#show_image_batch)

# %%
show_doc(show_images)

# %% [markdown]
# [<code>show_images</code>](http://docs.fast.ai/vision.image.html#show_images)

# %%
show_doc(show_xy_images)

# %% [markdown]
# [<code>show_xy_images</code>](http://docs.fast.ai/vision.data.html#show_xy_images)

# %%
show_doc(transform_datasets)

# %% [markdown]
# [<code>transform_datasets</code>](http://docs.fast.ai/vision.data.html#transform_datasets)
