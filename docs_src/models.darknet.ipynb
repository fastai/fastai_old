# %% [markdown]
# # models.darknet

# %% [markdown]
# Type an introduction of the package here.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.models.darknet import *

# %% [markdown]
# ### Global Variable Definitions:

# %%
show_doc(Darknet)
# Out:
# ### <a id=Darknet></a><em>class</em> `Darknet`
# (<code>num_blocks</code>:<code>int</code>, <code>num_classes</code>:<code>int</code>, <code>nf</code>=`32`) :: Inherits ([<code>Module</code>](https://pytorch.org/docs/stable/nn.html#torch.nn.Module))<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/models/darknet.py#L16">[source]</a></div>
#
#
# https://github.com/pjreddie/darknet

# %% [markdown]
# [<code>Darknet</code>](http://docs.fast.ai/models.darknet.html#Darknet)

# %%
show_doc(Darknet.forward)
# Out:
# #### <a id=forward></a>`forward`(<code>x</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/models/darknet.py#L33">[source]</a></div>
#
#
# Should be overridden by all subclasses.
#
# .. note::
#     Although the recipe for forward pass needs to be defined within
#     this function, one should call the :class:`Module` instance afterwards
#     instead of this since the former takes care of running the
#     registered hooks while the latter silently ignores them.

# %% [markdown]
# `Darknet.forward`

# %%
show_doc(Darknet.make_group_layer)
# Out:
# #### <a id=make_group_layer></a>`make_group_layer`
# (<code>ch_in</code>:<code>int</code>, <code>num_blocks</code>:<code>int</code>, <code>stride</code>:<code>int</code>=`1`)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/models/darknet.py#L18">[source]</a></div>
#
#
# starts with conv layer - `ch_in` channels in - then has `num_blocks` [<code>ResLayer</code>](fastai.models.darknet.html#ResLayer)

# %% [markdown]
# `Darknet.make_group_layer`

# %%
show_doc(ResLayer)
# Out:
# ### <a id=ResLayer></a><em>class</em> `ResLayer`(<code>ni</code>:<code>int</code>) :: Inherits ([<code>Module</code>](https://pytorch.org/docs/stable/nn.html#torch.nn.Module))<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/models/darknet.py#L6">[source]</a></div>
#
#
# Resnet style [<code>ResLayer</code>](fastai.models.darknet.html#ResLayer)

# %% [markdown]
# [<code>ResLayer</code>](http://docs.fast.ai/models.darknet.html#ResLayer)

# %%
show_doc(ResLayer.forward)
# Out:
# #### <a id=forward></a>`forward`(<code>x</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/models/darknet.py#L14">[source]</a></div>
#
#
# Should be overridden by all subclasses.
#
# .. note::
#     Although the recipe for forward pass needs to be defined within
#     this function, one should call the :class:`Module` instance afterwards
#     instead of this since the former takes care of running the
#     registered hooks while the latter silently ignores them.

# %% [markdown]
# `ResLayer.forward`
