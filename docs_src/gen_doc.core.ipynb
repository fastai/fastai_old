# %% [markdown]
# # gen_doc.core

# %% [markdown]
# Type an introduction of the package here.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.gen_doc.core import *

# %%
show_doc(strip_fastai)
# Out:
# #### <a id=strip_fastai></a>`strip_fastai`(<code>s</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/core.py#L4">[source]</a></div>

# %% [markdown]
# [<code>strip_fastai</code>](fastai.gen_doc.core.html#strip_fastai)
