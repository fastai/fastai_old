# %% [markdown]
# # gen_doc.docstrings

# %% [markdown]
# Type an introduction of the package here.

# %%
from fastai.gen_doc.nbdoc import *
from fastai.gen_doc.docstrings import *

# %% [markdown]
# ### Global Variable Definitions:

# %%
show_doc(parse_docstring)
# Out:
# #### <a id=parse_docstring></a>`parse_docstring`(<code>docstring</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/docstrings.py#L67">[source]</a></div>
#
#
# Parse the docstring into its components.
#
# *return*: a dictionary of form
# {
# "short_description": ...,
# "long_description": ...,
# "params": [{"name": ..., "doc": ...}, ...],
# "vals": [{"name": ..., "doc": ...}, ...],
# "return": ...
# }

# %% [markdown]
# [<code>parse_docstring</code>](fastai.gen_doc.docstrings.html#parse_docstring)
