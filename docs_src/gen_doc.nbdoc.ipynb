# %% [markdown]
# # Documentation notebook functions

# %%
from fastai.gen_doc.nbdoc import *
from fastai.gen_doc.nbdoc import *

# %% [markdown]
# `nbdoc` contains the functions for documentation notebooks. The most important is [`show_doc`](/gen_doc.nbdoc.html#show_doc):

# %%
show_doc(get_source_link)

# %%
show_doc(show_doc)
# Out:
# #### <a id=show_doc></a>`show_doc`
# (<code>elt</code>, <code>doc_string</code>:<code>bool</code>=`True`, <code>full_name</code>:<code>str</code>=`None`, <code>arg_comments</code>:<code>dict</code>=`None`, <code>title_level</code>=`None`, <code>alt_doc_string</code>:<code>str</code>=`''`, <code>ignore_warn</code>:<code>bool</code>=`False`)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L78">[source]</a></div>
#
#
# Show documentation for element `elt`. Supported types: class, Callable, and enum

# %% [markdown]
# In your notebook you'll have a call to [`show_doc`](/gen_doc.nbdoc.html#show_doc) for every symbol you wish to document. And you'll want to *hide input* for that cell. For instance, the above signature is generated by this function:
#
# ```python
# show_doc(show_doc)
# ```

# %% [markdown]
# ## Convenience functions

# %%
show_doc(show_video)
# Out:
# #### <a id=show_video></a>`show_video`(<code>url</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L215">[source]</a></div>

# %%
show_doc(show_video_from_youtube)
# Out:
# #### <a id=show_video_from_youtube></a>`show_video_from_youtube`
# (<code>code</code>, <code>start</code>=`0`)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L219">[source]</a></div>

# %%
show_doc(create_anchor)
# Out:
# #### <a id=create_anchor></a>`create_anchor`
# (<code>text</code>, <code>title_level</code>=`0`, <code>name</code>=`None`)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L257">[source]</a></div>

# %% [markdown]
# ## Functions for internal fastai library use

# %%
show_doc(get_exports)
# Out:
# #### <a id=get_exports></a>`get_exports`(<code>mod</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L148">[source]</a></div>

# %%
show_doc(get_fn_link)
# Out:
# #### <a id=get_fn_link></a>`get_fn_link`
# (<code>ft</code>) -> <code>str</code><div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L229">[source]</a></div>
#
#
# returns function link to notebook documentation

# %%
show_doc(get_ft_names)
# Out:
# #### <a id=get_ft_names></a>`get_ft_names`
# (<code>mod</code>) -> <code>List</code>[<code>str</code>]<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L153">[source]</a></div>
#
#
# Returns all the functions of module `mod`

# %%
show_doc(import_mod)
# Out:
# #### <a id=import_mod></a>`import_mod`
# (<code>mod_name</code>:<code>str</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L128">[source]</a></div>
#
#
# returns module from `mod_name`

# %%
show_doc(link_docstring)
# Out:
# #### <a id=link_docstring></a>`link_docstring`
# (<code>elt</code>, <code>docstring</code>:<code>str</code>) -> <code>str</code><div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L116">[source]</a></div>
#
#
# searches `docstring` for backticks and attempts to link those functions to respective documentation

# %% [markdown]
# ## Obsolete functions

# %%
show_doc(show_doc_from_name)
# Out:
# #### <a id=show_doc_from_name></a>`show_doc_from_name`
# (<code>mod_name</code>, <code>ft_name</code>:<code>str</code>, <code>doc_string</code>:<code>bool</code>=`True`, <code>arg_comments</code>:<code>dict</code>=`{}`, <code>alt_doc_string</code>:<code>str</code>=`''`)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L137">[source]</a></div>
#
#
# shows documentation for `ft_name`. see [<code>show_doc</code>](http://docs.fast.ai/gen_doc.nbdoc.html#show_doc)

# %%
show_doc(get_class_toc)
# Out:
# #### <a id=get_class_toc></a>`get_class_toc`
# (<code>mod_name</code>:<code>str</code>, <code>cls_name</code>:<code>str</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L196">[source]</a></div>
#
#
# displays table of contents for `cls_name`

# %%
show_doc(get_module_toc)
# Out:
# #### <a id=get_module_toc></a>`get_module_toc`(<code>mod_name</code>)<div style="text-align: right"><a href="https://github.com/fastai/fastai_pytorch/blob/master/fastai/gen_doc/nbdoc.py#L181">[source]</a></div>
#
#
# displays table of contents for given `mod_name`
