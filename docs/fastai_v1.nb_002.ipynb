# %% [markdown]
# # fastai_v1.nb_002

# %% [markdown]
# Type an introduction of the package here.

# %% [markdown]
# **FakeTestClass**
#
# Arguments:
# - **a** (<class 'int'>):
# - **b** (<class 'float'>), *default 0.5*:

# %% [markdown]
# **FilesDataset** (subclass of <class 'torch.utils.data.dataset.Dataset'>)
#
# Arguments:
# - **folder**:
# - **classes**, *default None*:

# %% [markdown]
# **TfmType** (enumerator class)
#
# Values:
# - **Lighting**:
#
# - **Coord**:
#
# - **Affine**:
#
# - **Pixel**:
#
# - **Final**:

# %% [markdown]
# **affine_grid**
#
# Arguments:
# - **x**:
# - **matrix**:
# - **size**, *default None*:

# %% [markdown]
# **affines_mat**
#
# Arguments:
# - **matrices**, *default None*:

# %% [markdown]
# **apply_affine_tfm**
#
# Arguments:
# - **matrices**, *default None*:
# - **func**, *default None*:

# %% [markdown]
# **apply_lighting_tfm**
#
# Arguments:
# - **func**:

# %% [markdown]
# **brightness**
#
# Arguments:
# - **x**:
# - **change** (<function uniform at 0x00000209B37DED08>):

# %% [markdown]
# **brightness_tfm**
#
# Arguments:

# %% [markdown]
# **contrast**
#
# Arguments:
# - **x**:
# - **scale** (<function log_uniform at 0x00000209B39F9B70>):

# %% [markdown]
# **contrast_tfm**
#
# Arguments:

# %% [markdown]
# **denormalize**
#
# Arguments:
# - **mean**:
# - **std**:
# - **x**:

# %% [markdown]
# **do_affine**
#
# Arguments:
# - **img**:
# - **m**, *default None*:
# - **func**, *default None*:
# - **size**, *default None*:

# %% [markdown]
# **eye_new**
#
# Arguments:
# - **x**:
# - **n**:

# %% [markdown]
# **find_classes**
#
# Arguments:
# - **folder**:

# %% [markdown]
# **flip_lr**
#
# Arguments:
# - **x**:

# %% [markdown]
# **flip_lr_tfm**
#
# Arguments:

# %% [markdown]
# **get_batch_stats**
#
# Arguments:
# - **dl**:

# %% [markdown]
# **get_image_files**
#
# Arguments:
# - **c**:

# %% [markdown]
# **grid_sample**
#
# Arguments:
# - **x**:
# - **coords**:
# - **mode**, *default bilinear*:
# - **padding_mode**, *default reflect*:

# %% [markdown]
# **grid_sample_nearest**
#
# Arguments:
# - **input**:
# - **coords**:
# - **padding_mode**, *default zeros*:

# %% [markdown]
# **image2np**
#
# Arguments:
# - **image**:

# %% [markdown]
# **jitter**
#
# Arguments:
# - **x**:
# - **magnitude** (<function uniform at 0x00000209B37DED08>):

# %% [markdown]
# **jitter_tfm**
#
# Arguments:

# %% [markdown]
# **log_uniform**
#
# Arguments:
# - **low**:
# - **high**:
# - **size**, *default None*:

# %% [markdown]
# **logit**
#
# Arguments:
# - **x**:

# %% [markdown]
# **logit_**
#
# Arguments:
# - **x**:

# %% [markdown]
# **make_p_affine**
#
# Arguments:
# - **func**:

# %% [markdown]
# **make_p_func**
#
# Arguments:
# - **func**:

# %% [markdown]
# **make_tfm_affine**
#
# Arguments:
# - **func**:

# %% [markdown]
# **make_tfm_func**
#
# Arguments:
# - **func**:

# %% [markdown]
# **noop**
#
# Arguments:
# - **x**:

# %% [markdown]
# **normalize**
#
# Arguments:
# - **mean**:
# - **std**:
# - **x**:

# %% [markdown]
# **pil2tensor**
#
# Arguments:
# - **image**:

# %% [markdown]
# **rand_bool**
#
# Arguments:
# - **p**, *default 1*:
# - **size**, *default None*:

# %% [markdown]
# **randint**
#
# Arguments:
# - **low**:
# - **high**:
# - **size**, *default None*:

# %% [markdown]
# **reg_affine**
#
# Arguments:
# - **func**:

# %% [markdown]
# **reg_transform**
#
# Arguments:
# - **func**:

# %% [markdown]
# **resolve_args**
#
# Arguments:
# - **func**:

# %% [markdown]
# **resolve_tfms**
#
# Arguments:
# - **tfms**:

# %% [markdown]
# **rotate**
#
# Arguments:
# - **degrees** (<function uniform at 0x00000209B37DED08>):

# %% [markdown]
# **rotate_tfm**
#
# Arguments:

# %% [markdown]
# **show_image**
#
# Arguments:
# - **img**:
# - **ax**, *default None*:
# - **figsize**, *default (3, 3)*:
# - **hide_axis**, *default True*:

# %% [markdown]
# **show_image_batch**
#
# Arguments:
# - **dl**:
# - **classes**:
# - **rows**, *default None*:

# %% [markdown]
# **show_images**
#
# Arguments:
# - **x**:
# - **y**:
# - **rows**:
# - **classes**:
# - **figsize**, *default (12, 15)*:

# %% [markdown]
# **uniform**
#
# Arguments:
# - **low**, *default 0*:
# - **high**, *default 1*:
# - **size**, *default None*:

# %% [markdown]
# **xy_transform**
#
# Arguments:
# - **x_tfm**, *default None*:
# - **y_tfm**, *default None*:

# %% [markdown]
# **xy_transforms**
#
# Arguments:
# - **x_tfms**, *default None*:
# - **y_tfms**, *default None*:

# %% [markdown]
# **zoom**
#
# Arguments:
# - **scale** (<function uniform at 0x00000209B37DED08>):

# %% [markdown]
# **zoom_tfm**
#
# Arguments:
